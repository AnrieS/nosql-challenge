# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
import pandas as pd
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
establishments.find_one()
# Out:
# {'_id': ObjectId('6607ac5dccb75fe704e52f98'),
#  'FHRSID': 1043695,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6BL',
#  'Phone': '',
#  'RatingValue': 5,
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2018-04-04T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 1.195625, 'latitude': 51.083812},
#  'RightToReply': '',
#  'Distance': 4591.765489457773,
#  'NewRatingPending': False,
# ...

# %%
# Find the establishments with a hygiene score of 20
query ={"scores.Hygiene": {"$eq": 20}}

# Use count_documents to display the number of documents in the result
num_hygiene = establishments.count_documents(query)
# Display the first document in the results using pprint
print(f"The Number of documents in the establisment with hygiene score of 20 are: {num_hygiene}")

print("---------------------")
first_doc = list(establishments.find({"scores.Hygiene": {"$eq": 20}}))
for i in range(1):
    pprint(first_doc[i])
# Out:
# The Number of documents in the establisment with hygiene score of 20 are: 41
# ---------------------
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': None,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6607ac5eccb75fe704e54acb'),
#  'geocode': {'latitude': 50.769705, 'longitude': 0.27694},
# ...

# %%
# Convert the result to a Pandas DataFrame
df = pd.DataFrame(first_doc)
# Display the number of rows in the DataFrame
num_rows = 0
for i in df.index:
    num_rows += 1
    
print(f"The number of rows are: {num_rows}")

# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
# The number of rows are: 41
#                         _id   FHRSID  ChangesByServerID  \
# 0  6607ac5eccb75fe704e54acb   110681                  0
# 1  6607ac5eccb75fe704e54e4b   612039                  0
# 2  6607ac5eccb75fe704e55157   730933                  0
# 3  6607ac5eccb75fe704e55344   172735                  0
# 4  6607ac5eccb75fe704e55354   172953                  0
# 5  6607ac5eccb75fe704e55d07   512854                  0
# 6  6607ac5eccb75fe704e55f1f  1537089                  0
# 7  6607ac5fccb75fe704e5743b   155648                  0
# 8  6607ac5fccb75fe704e57896  1012883                  0
# 9  6607ac5fccb75fe704e58095   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query ={ 'LocalAuthorityName': {'$regex':'London'}, 'RatingValue': {'$gte': 4} }
results = establishments.find(query)
# Use count_documents to display the number of documents in the result
count_documents = establishments.count_documents(query)

print(f'There are {count_documents} establishments with London as the Local Authority and has a rating value >= 4')
# Out:
# There are 33 establishments with London as the Local Authority and has a rating value >= 4

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {"LocalAuthorityName": {"$regex": "London"}, "RatingValue" : {"$gte": 4}}

# Use count_documents to display the number of documents in the result
london_ratingvalue_4 = establishments.count_documents(query)
first_document_list = list(establishments.find({"LocalAuthorityName": {"$regex": "London"},  "RatingValue": {"$gte": 4}}))
print(london_ratingvalue_4)
# Display the first document in the results using pprint
if first_document_list:
    
    first_document = first_document_list[0]
    pprint(first_document)
    
else:
    print("There are no documents in this list")
# Out:
# 33
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6607ac5eccb75fe704e564e3'),
#  'geocode': {'latitude': 51.369321, 'longitude': 0.508551},
# ...

# %%
# Convert the result to a Pandas DataFrame
df_london_rating = pd.DataFrame(first_document_list)
# Display the number of rows in the DataFrame
num_rows = df_london_rating.shape[0]
print(num_rows)
# Display the first 10 rows of the DataFrame
df_london_rating.head(10)
# Out:
# 33
#                         _id   FHRSID  ChangesByServerID  \
# 0  6607ac5eccb75fe704e564e3   621707                  0
# 1  6607ac5eccb75fe704e5680e  1130836                  0
# 2  6607ac5fccb75fe704e57369   293783                  0
# 3  6607ac5fccb75fe704e5815b  1315095                  0
# 4  6607ac5fccb75fe704e5815c   294474                  0
# 5  6607ac5fccb75fe704e58860   294900                  0
# 6  6607ac60ccb75fe704e5a972   293756                  0
# 7  6607ac60ccb75fe704e5ad33   878523                  0
# 8  6607ac60ccb75fe704e5ad51   295107                  0
# 9  6607ac60ccb75fe704e5ad58   294606                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# 3             PI/000036464  Coombs Catering t/a The Lock and Key
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 51.49014200
longitude = 0.08384000

query = {"RatingValue": {"$eq": 5}, 
         "geocode.longitude": {"$gte": degree_search-longitude, "$lte": degree_search+longitude},
         "geocode.latitude": {"$gte": degree_search-latitude, "$lte": degree_search+latitude}
}
sort = [("scores.Hygiene", 1)]
limit = 10

# Print the results
documents = establishments.find(query).sort(sort).limit(limit)

for document in documents:
    print(document)
# Out:
# {'_id': ObjectId('6607ac5fccb75fe704e58afa'), 'FHRSID': 105360, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': '36199', 'BusinessName': 'Wolfe House Resid. Home', 'BusinessType': 'Caring Premises', 'BusinessTypeID': 5, 'AddressLine1': 'Wolf House', 'AddressLine2': 'Wolfs Row', 'AddressLine3': '', 'AddressLine4': 'Limpsfield', 'PostCode': 'RH8 0EB', 'Phone': '', 'RatingValue': 5, 'RatingKey': 'fhrs_5_en-gb', 'RatingDate': '2022-06-14T00:00:00', 'LocalAuthorityCode': '313', 'LocalAuthorityName': 'Tandridge', 'LocalAuthorityWebSite': 'http://www.tandridge.gov.uk/', 'LocalAuthorityEmailAddress': 'fsa_enforcement@tandridge.gov.uk', 'scores': {'Hygiene': None, 'Structural': None, 'ConfidenceInManagement': None}, 'SchemeType': 'FHRS', 'geocode': {'longitude': 0.015813, 'latitude': 51.255431}, 'RightToReply': '', 'Distance': 4641.271316270499, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0
# ...

# %%
# Convert result to Pandas DataFrame
document_list = list(documents)
df_geo = pd.DataFrame(document_list)

df_geo
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that:
# 1. Matches establishments with a hygiene score of 0
hygiene_0 = {"$match": {"scores.Hygiene" : {"$eq": 0 }}}


# 2. Groups the matches by Local Authority
group_query = {"$group" : {"_id": "$LocalAuthorityName", "count" : {"$sum": 1}}}


# 3. Sorts the matches from highest to lowest
sorted_values = {"$sort": {"count": -1}}


# Print the number of documents in the result
pipeline = [hygiene_0, group_query, sorted_values]
results = list(establishments.aggregate(pipeline))

# Print the first 10 results
pprint(results[0:10])
# Out:
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame
df_4 = pd.DataFrame(results)
# Display the number of rows in the DataFrame
num_rows = 0
for i in df_4.index:
    num_rows += 1
print(f"The Number of Rows in the DataFrame is {num_rows}")
# Display the first 10 rows of the DataFrame
df_4.head(10)
# Out:
# The Number of Rows in the DataFrame is 55
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
